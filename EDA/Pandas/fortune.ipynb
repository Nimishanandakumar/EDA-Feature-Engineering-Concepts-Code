# %%
import numpy as np
import pandas as pd

# %%
company = pd.read_csv("Fortune 500 Companies US.csv",encoding='latin-1')
company

# %%
len(company)
len(sectors)
sectors.size()
sectors.size().sort_values(ascending=False)
sectors.first()
sectors.last()
sectors.groups
company.iloc[23,:]
sectors.get_group('Energy')
sectors.get_group('Energy').shape
sectors.sum()
sectors.mean()
sectors['Revenues'].mean().sort_values()
